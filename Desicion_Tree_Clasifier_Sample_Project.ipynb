# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Load data
Data = pd.read_csv('/content/adult_income_dataset_2500.csv')
Data
# Out:
#       age         workclass  fnlwgt     education  education_num  \
# 0      44       Federal-gov  112501  Some-college              3
# 1      67           Private  364691          11th             16
# 2      35         State-gov  382272       Masters              8
# 3      40           Private  289913       HS-grad              6
# 4      48           Private  487175       Masters              7
# ...   ...               ...     ...           ...            ...
# 2495   31  Self-emp-not-inc  361305  Some-college             12
# 2496   56  Self-emp-not-inc  144268    Assoc-acdm             13
# 2497   46       Federal-gov  139789          11th             14
# 2498   50         State-gov   17010  Some-college              7
# 2499   57           Private  141596       HS-grad              4
#
#           marital_status         occupation   relationship  \
# 0                Widowed     Prof-specialty      Own-child
# 1                Widowed    Exec-managerial  Not-in-family
# ...

# %%
#claen data
Data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
#convert data into input and output

X = Data.drop(columns=['income'])
X
# Out:
#       age         workclass  fnlwgt     education  education_num  \
# 0      44       Federal-gov  112501  Some-college              3
# 1      67           Private  364691          11th             16
# 2      35         State-gov  382272       Masters              8
# 3      40           Private  289913       HS-grad              6
# 4      48           Private  487175       Masters              7
# ...   ...               ...     ...           ...            ...
# 2495   31  Self-emp-not-inc  361305  Some-college             12
# 2496   56  Self-emp-not-inc  144268    Assoc-acdm             13
# 2497   46       Federal-gov  139789          11th             14
# 2498   50         State-gov   17010  Some-college              7
# 2499   57           Private  141596       HS-grad              4
#
#           marital_status         occupation   relationship  \
# 0                Widowed     Prof-specialty      Own-child
# 1                Widowed    Exec-managerial  Not-in-family
# ...

# %%
y = Data[['income']]
y
# Out:
#      income
# 0      >50K
# 1      >50K
# 2     <=50K
# 3     <=50K
# 4      >50K
# ...     ...
# 2495   >50K
# 2496   >50K
# 2497  <=50K
# 2498   >50K
# 2499  <=50K
#
# [2500 rows x 1 columns]

# %%
#implement standard scaler

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[ 0.00958091, -1.02010584, -1.16802284, ..., -0.50124969,
#          2.02534955, -0.49749873],
#        [ 1.49050143,  0.7615068 ,  1.64013978, ...,  1.9950137 ,
#         -0.49374193, -0.49749873],
#        [-0.56990972,  0.88570891, -0.08796029, ..., -0.50124969,
#         -0.49374193,  2.01005537],
#        ...,
#        [ 0.13835661, -0.82732799,  1.20811476, ..., -0.50124969,
#         -0.49374193, -0.49749873],
#        [ 0.395908  , -1.69470821, -0.3039728 , ..., -0.50124969,
#          2.02534955, -0.49749873],
#        [ 0.84662294, -0.81456232, -0.95201033, ...,  1.9950137 ,
#         -0.49374193, -0.49749873]])

# %%
#train_test_split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.9 , random_state=40)

# %%
#model building
from sklearn.tree import DecisionTreeClassifier
Model = DecisionTreeClassifier()

# %%
Model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = Model.predict(X_test)
y_pred
# Out:
# array(['<=50K', '<=50K', '>50K', '<=50K', '>50K', '>50K', '<=50K', '>50K',
#        '<=50K', '>50K', '>50K', '<=50K', '<=50K', '>50K', '<=50K',
#        '<=50K', '<=50K', '<=50K', '<=50K', '<=50K', '<=50K', '<=50K',
#        '<=50K', '>50K', '<=50K', '<=50K', '>50K', '>50K', '<=50K',
#        '<=50K', '>50K', '>50K', '>50K', '<=50K', '<=50K', '>50K', '<=50K',
#        '>50K', '>50K', '>50K', '>50K', '<=50K', '>50K', '>50K', '>50K',
#        '>50K', '>50K', '<=50K', '<=50K', '>50K', '>50K', '>50K', '>50K',
#        '<=50K', '>50K', '<=50K', '>50K', '<=50K', '>50K', '<=50K', '>50K',
#        '>50K', '<=50K', '>50K', '>50K', '>50K', '>50K', '>50K', '<=50K',
#        '<=50K', '<=50K', '<=50K', '>50K', '<=50K', '<=50K', '>50K',
#        '>50K', '>50K', '>50K', '>50K', '<=50K', '<=50K', '>50K', '>50K',
#        '>50K', '<=50K', '<=50K', '>50K', '>50K', '<=50K', '>50K', '>50K',
#        '>50K', '>50K', '<=50K', '>50K', '>50K', '<=50K', '>50K', '>50K',
# ...

# %%
#accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(y_pred,y_test))
# Out:
# 0.496

# %%
#our model is 49.60% accurate

# %%
#
